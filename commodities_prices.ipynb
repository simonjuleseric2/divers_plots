# %%
import matplotlib.pyplot as plt
#from matplotlib.pyplot import *
import quandl
from matplotlib.font_manager import FontProperties

# %%
commod = []
commod.append("CHRIS/CME_W1")

quandl.ApiConfig.api_key = "Zzg6mpfNEhhxpDHagX6x"
#series = quandl.get(commod,trim_start="1990-01-01", trim_end="2020-12-01",collapse="annual")
series = quandl.get(commod,trim_start="1990-01-01", trim_end="2020-12-01",collapse="monthly")
dateaxis = series.reset_index()['Date']
#ax1=series.ix
ax1=series.values
ax2=ax1[:, 0]

plt.plot(dateaxis, ax2, marker='.')
plt.xlabel("Year")
plt.ylabel("prices")
plt.show()
